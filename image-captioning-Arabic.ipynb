# %% [markdown]
# <b> T5 Data Science Bootcamp</b>

# %% [markdown]
# <img src="logo.png"  width=800 height=800/>

# %% [markdown]
# By:
# Amirah Alotaibi ,Alanoud Alhussain ,Amal Altamran ,Batoul AlOsaimi ,Shroaq Abdullah ,Norah Alqahtani and Asma Alsulami

# %% [markdown]
# ### Introduction:
# Image caption Generator is a popular research area of Artificial Intelligence that deals with image understanding and a language description for that image. Automatic generation of an image description requires both computer vision and natural language processing techniques. And from this point we decide to help people with disabilities as well as early childhood education By doing image caption English and Arabic and transformed to voice using artificial intelligence technology so, their lives can be improved.

# %% [markdown]
# ## Table of Contents:

# %% [markdown]
# <li><a id='Libraries'> Libraries</a></li>
# <li><a id='1. load data'> 1. load data</a></li>
# <li><a id=' 2. Pre-Processing the captions'>2.Pre-Processing the captions</a></li>
# <li><a id='3.Pre-Processing the images'>3.Pre-Processing the images</a></li>
# <li><a id='4. Create the train & test data '>4. Create the train & test data  </a></li>
# <li><a id='5. transfer learning'>5. transfer learning</a></li>
# <li><a id='6. Extract the features from images'>6. Extract the features from images</a></li>
# <li><a id='7.Model Building'>7. Model Building</a></li>
# <li><a id='8. Model Evaluation'>8. Model Evaluation</a></li>
# <li><a id='9.Convert Text-to-speech'>9.Convert Text-to-speech</a></li>

# %% [markdown]
# ## Libraries

# %%
#Import all the required libraries
import os, glob
from glob import glob
import pickle
from sys import getsizeof

import numpy as np
import pandas as pd
import collections, random, re
from collections import Counter

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from skimage import io

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Layer, Dense, Embedding, GRU
from tensorflow.nn import relu, tanh, softmax

import matplotlib.pyplot as plt

from nltk.translate.bleu_score import sentence_bleu

from PIL import Image

import warnings
warnings.filterwarnings("ignore")

# %%
from bidi import algorithm as bidialg

# %% [markdown]
# ## load data

# %%
images= '/Users/norahalqahtani/DatascienceBootcamp/Deep-Learning/Final-Project/AAA/Arabic-Image-Captioning/data/Flickr8k_Dataset/Flicker8k_Dataset/'

all_imgs = glob(images + '/*.jpg',recursive=True)
print("The total images present in the dataset: {}".format(len(all_imgs)))
# Out:
# The total images present in the dataset: 8091

# %%
all_imgs[-1]
# Out:
# '/Users/norahalqahtani/DatascienceBootcamp/Deep-Learning/Final-Project/AAA/Arabic-Image-Captioning/data/Flickr8k_Dataset/Flicker8k_Dataset/2764732789_1392e962d0.jpg'

# %%
type(all_imgs)
# Out:
# list

# %%
col_names = ["image", "captions"]
captions = pd.read_csv("Flickr8k.arabic.full.txt", sep='\t',  error_bad_lines=False, names=col_names)
captions.head()
# Out:
#                          image  \
# 0  1000268201_693b08cb0e.jpg#0
# 1  1000268201_693b08cb0e.jpg#1
# 2  1000268201_693b08cb0e.jpg#2
# 3  1001773457_577c3a7d70.jpg#0
# 4  1001773457_577c3a7d70.jpg#1
#
#                                             captions
# 0                     طفلة صغيرة تتسلق إلى مسرح خشبي
# 1                  طفلة صغيرة تتسلق الدرج إلى منزلها
# 2   فتاة صغيرة في ثوب وردي تذهب إلى المقصورة الخشبية
# 3  كلب أسود وكلب ثلاثي الألوان يلعبان مع بعضهما ا...
# 4  كلب أسود وكلب أبيض ببقع بنية يحدقان في بعضهما ...

# %% [markdown]
# Create a dataframe which summarizes the image, path & captions as a dataframe
#
# Each image id has 3 captions associated with it therefore the total dataset should have 24273 samples.

# %%
captions
# Out:
#                              image  \
# 0      1000268201_693b08cb0e.jpg#0
# 1      1000268201_693b08cb0e.jpg#1
# 2      1000268201_693b08cb0e.jpg#2
# 3      1001773457_577c3a7d70.jpg#0
# 4      1001773457_577c3a7d70.jpg#1
# ...                            ...
# 24268   997338199_7343367d7f.jpg#1
# 24269   997338199_7343367d7f.jpg#2
# 24270   997722733_0cb5439472.jpg#0
# 24271   997722733_0cb5439472.jpg#1
# 24272   997722733_0cb5439472.jpg#2
#
#                                                 captions
# 0                         طفلة صغيرة تتسلق إلى مسرح خشبي
# 1                      طفلة صغيرة تتسلق الدرج إلى منزلها
# 2       فتاة صغيرة في ثوب وردي تذهب إلى المقصورة الخشبية
# 3      كلب أسود وكلب ثلاثي الألوان يلعبان مع بعضهما ا...
# 4      كلب أسود وكلب أبيض ببقع بنية يحدقان في بعضهما ...
# ...                                                  ...
# 24268                امرأة تقف بالقرب من جدار مزخرف تكتب
# 24269                      الجدران مغطاة بالذهب والأنماط
# 24270         رجل يرتدي قميصًا ورديًا يتسلق وجهًا صخريًا
# 24271                         رجل يتسلق الصخور في الهواء
# 24272                            متسلق صخرة في قميص أحمر
#
# [24273 rows x 2 columns]

# %%
df = captions.copy()
df.columns = ['ID','Captions']

# %%
ids=[]
for d in df['ID']:
    t=re.sub('#[\d.-]+', '', d)
    ids.append(t)

# %%
len(ids)
# Out:
# 24273

# %%
df['ID']=ids
df['Path'] = images + "/" + df['ID']

all_img_id= df['ID']
all_img_vector= df['Path']
annotations= df['Captions']

df
# Out:
#                               ID  \
# 0      1000268201_693b08cb0e.jpg
# 1      1000268201_693b08cb0e.jpg
# 2      1000268201_693b08cb0e.jpg
# 3      1001773457_577c3a7d70.jpg
# 4      1001773457_577c3a7d70.jpg
# ...                          ...
# 24268   997338199_7343367d7f.jpg
# 24269   997338199_7343367d7f.jpg
# 24270   997722733_0cb5439472.jpg
# 24271   997722733_0cb5439472.jpg
# 24272   997722733_0cb5439472.jpg
#
#                                                 Captions  \
# 0                         طفلة صغيرة تتسلق إلى مسرح خشبي
# 1                      طفلة صغيرة تتسلق الدرج إلى منزلها
# 2       فتاة صغيرة في ثوب وردي تذهب إلى المقصورة الخشبية
# 3      كلب أسود وكلب ثلاثي الألوان يلعبان مع بعضهما ا...
# 4      كلب أسود وكلب أبيض ببقع بنية يحدقان في بعضهما ...
# ...                                                  ...
# 24268                امرأة تقف بالقرب من جدار مزخرف تكتب
# 24269                      الجدران مغطاة بالذهب والأنماط
# 24270         رجل يرتدي قميصًا ورديًا يتسلق وجهًا صخريًا
# 24271                         رجل يتسلق الصخور في الهواء
# 24272                            متسلق صخرة في قميص أحمر
#
#                                                     Path
# 0      /Users/norahalqahtani/DatascienceBootcamp/Deep...
# 1      /Users/norahalqahtani/DatascienceBootcamp/Deep...
# 2      /Users/norahalqahtani/DatascienceBootcamp/Deep...
# 3      /Users/norahalqahtani/DatascienceBootcamp/Deep...
# 4      /Users/norahalqahtani/DatascienceBootcamp/Deep...
# ...                                                  ...
# 24268  /Users/norahalqahtani/DatascienceBootcamp/Deep...
# 24269  /Users/norahalqahtani/DatascienceBootcamp/Deep...
# 24270  /Users/norahalqahtani/DatascienceBootcamp/Deep...
# 24271  /Users/norahalqahtani/DatascienceBootcamp/Deep...
# 24272  /Users/norahalqahtani/DatascienceBootcamp/Deep...
#
# [24273 rows x 3 columns]

# %% [markdown]
# >  in cells bellow gave id nummber for each single word in captions in the dataset to make it easer to learn in the model **vocabs** is the dataframe that contain tis information

# %%
def get_vocab(captions):
    vocabs = map(lambda caption: re.split("\W+", caption), captions)
    return (word for vocab in vocabs for word in vocab if word != "")

# %%
#Create the vocabulary & the counter for the captions

vocabulary= list(get_vocab(df.Captions))

val_count=Counter(vocabulary)
print(val_count['أخضر'])
print(val_count['صبي'])
# Out:
# 183
# 1700

# %%
val_count
# Out:
# Counter({'طفلة': 102,
#          'صغيرة': 816,
#          'تتسلق': 69,
#          'إلى': 978,
#          'مسرح': 8,
#          'خشبي': 117,
#          'الدرج': 54,
#          'منزلها': 3,
#          'فتاة': 1566,
#          'في': 11109,
#          'ثوب': 169,
#          'وردي': 148,
#          'تذهب': 3,
#          'المقصورة': 1,
#          'الخشبية': 11,
#          'كلب': 4118,
#          'أسود': 1056,
#          'وكلب': 189,
#          'ثلاثي': 6,
#          'الألوان': 35,
#          'يلعبان': 333,
#          'مع': 2299,
#          'بعضهما': 140,
#          'البعض': 242,
#          'على': 7574,
#          'الطريق': 159,
#          'أبيض': 1164,
#          'ببقع': 3,
#          'بنية': 82,
#          'يحدقان': 12,
#          'الشارع': 355,
#          'كلاب': 299,
#          'الرصيف': 168,
#          'تتحرك': 10,
#          'نحو': 168,
#          'بعضها': 57,
#          'مغطاة': 67,
#          'بالطلاء': 6,
#          'تجلس': 263,
#          'أمام': 862,
#          'قوس': 16,
#          'قزح': 14,
#          'ملون': 33,
#          'كبير': 442,
#          'لوحة': 44,
#          'رجل': 4029,
#          'يجلس': 653,
#          'مقعد': 228,
#          'بينما': 936,
#          'كلبه': 46,
#          'بجانبه': 35,
#          'ينام': 47,
#          'الخارج': 206,
#          'وأسود': 348,
#          'بلا': 95,
#          'قميص': 802,
#          'الحديقة': 133,
#          'يرتدي': 1802,
#          'قبعة': 369,
#          'برتقالية': 157,
#          'ونظارات': 49,
#          'الرجل': 335,
#          'ذو': 283,
#          'الأذن': 2,
#          'المثقوبة': 1,
#          'نظارات': 114,
#          'وقبعة': 89,
#          'اللون': 341,
#          'طفل': 1032,
#          'يلعب': 837,
#          'حبل': 89,
#          'الحبل': 42,
#          'الأحمر': 217,
#          'صغير': 1419,
#          'يمسك': 168,
#          'بالحبال': 10,
#          'الحمراء': 94,
#          'الملعب': 146,
#          'يركض': 988,
#          'حديقة': 192,
#          'عشبية': 90,
#          'محاطة': 23,
#          'بسياج': 5,
#          'العشب': 917,
#          'يمتد': 48,
#          'الأخضر': 159,
#          'بالقرب': 558,
#          'من': 4723,
#          'سياج': 107,
#          'يهز': 31,
#          'رأسه': 94,
#          'الشاطئ': 623,
#          'كرة': 1444,
#          'حمراء': 538,
#          'يهتز': 3,
#          'حافة': 118,
#          'الماء': 1288,
#          'صبي': 1700,
#          'يبتسم': 130,
#          'حائط': 32,
#          'صخري': 172,
#          'مدينة': 62,
#          'يسير': 314,
#          'شارع': 163,
#          'مرصوف': 18,
#          'بالحجارة': 4,
#          'عمود': 36,
#          'معدني': 38,
#          'ورجل': 73,
#          'خلفه': 60,
#          'يقفز': 1466,
#          'فوق': 806,
#          'الجذع': 2,
#          'رمادي': 119,
#          'شجرة': 206,
#          'ساقطة': 17,
#          'جذع': 32,
#          'وأبيض': 128,
#          'يمر': 231,
#          'عبر': 764,
#          'الثلج': 778,
#          'القبعة': 14,
#          'يعرض': 3,
#          'صور': 17,
#          'ا': 1358,
#          'بجوار': 154,
#          'أحد': 214,
#          'المتزلجين': 78,
#          'زرقاء': 388,
#          'متسابق': 77,
#          'ينظر': 340,
#          'الصور': 31,
#          'المؤطرة': 1,
#          'الأشجار': 87,
#          'الزلاجات': 8,
#          'يبحث': 22,
#          'عن': 122,
#          'عمل': 6,
#          'فني': 14,
#          'للبيع': 3,
#          'لشخص': 5,
#          'واحد': 159,
#          'يتسلق': 284,
#          'جرف': 82,
#          'مجموعة': 884,
#          'الناس': 1013,
#          'الصخور': 224,
#          'جدار': 215,
#          'تسلق': 67,
#          'يتسلقون': 25,
#          'صخرة': 230,
#          'بني': 786,
#          'يطارد': 157,
#          'الخرطوم': 2,
#          'خرطوم': 12,
#          'يستعد': 82,
#          'للقبض': 138,
#          'جسم': 65,
#          'حقل': 568,
#          'السيارات': 31,
#          'القريبة': 6,
#          'جاهز': 5,
#          'صفراء': 203,
#          'تحلق': 27,
#          'الهواء': 776,
#          'خلف': 92,
#          'للحصول': 51,
#          'لعبة': 546,
#          'يحاول': 173,
#          'التقاط': 40,
#          'الجو': 105,
#          'عشبي': 161,
#          'وامرأة': 285,
#          'المياه': 180,
#          'كبيرة': 371,
#          'بحيرة': 141,
#          'يراقب': 124,
#          'بطة': 14,
#          'شخصان': 299,
#          'زوجان': 101,
#          'يجلسان': 194,
#          'رضيع': 13,
#          'وعربة': 2,
#          'أطفال': 327,
#          'طفلهما': 4,
#          'المولود': 1,
#          'حديث': 4,
#          'تحت': 203,
#          'تواجه': 8,
#          'بجانب': 459,
#          'عربة': 114,
#          'الأطفال': 288,
#          'الكلب': 589,
#          'الاسود': 7,
#          'يرشش': 4,
#          'يحفر': 37,
#          'حفرة': 31,
#          'الجليد': 203,
#          'شخص': 883,
#          'يقف': 1060,
#          'متجمدة': 5,
#          'بيضاء': 299,
#          'تلعب': 350,
#          'اثنين': 892,
#          'الكلاب': 664,
#          'يلعبون': 407,
#          'معا': 186,
#          'طول': 221,
#          'الرملي': 13,
#          'متسلق': 63,
#          'سترة': 433,
#          'والسراويل': 15,
#          'السوداء': 135,
#          'يحمل': 769,
#          'شيئ': 43,
#          'لديه': 94,
#          'فمه': 496,
#          'شيء': 108,
#          'أزرق': 413,
#          'ورضيع': 4,
#          'قوارب': 44,
#          'الكاياك': 34,
#          'الصفراء': 64,
#          'وولد': 14,
#          'سترات': 35,
#          'النجاة': 10,
#          'الزرقاء': 103,
#          'يجذفون': 1,
#          'زورق': 62,
#          'أصفر': 228,
#          'وصبي': 53,
#          'يركبان': 63,
#          'يقفزان': 50,
#          'بلعبة': 31,
#          'فناء': 46,
#          'ينقض': 4,
#          'الجسم': 6,
#          'هوكي': 37,
#          'حارس': 28,
#          'المرمى': 37,
#          'حلبة': 23,
#          'الهوكي': 83,
#          'شاب': 209,
#          'راكع': 2,
#          'هدف': 21,
#          'عصا': 183,
#          'يده': 53,
#          'اليمنى': 8,
#          'ويقرأ': 11,
#          'صحيفة': 13,
#          'تمثال': 43,
#          'مبنى': 269,
#          'يتم': 124,
#          'وضع': 15,
#          'خيمة': 39,
#          'رجلان': 303,
#          'يقفان': 209,
#          'جليد': 4,
#          'يبحثان': 6,
#          'مغطى': 90,
#          'بقماش': 2,
#          'خارج': 229,
#          'هيكل': 33,
#          'سطح': 51,
#          'ثلجي': 145,
#          'امرأة': 1551,
#          'تجثم': 3,
#          'ثلاثة': 640,
#          'ويجلس': 6,
#          'الشخص': 116,
#          'بجانبهم': 3,
#          'تلة': 179,
#          'ناطحة': 2,
#          'سحاب': 3,
#          'طويل': 106,
#          'للغاية': 13,
#          'يقضم': 7,
#          'سلعة': 1,
#          'مخبوزة': 1,
#          'يضع': 51,
#          'بكلتا': 3,
#          'يديه': 29,
#          'الصبي': 151,
#          'يأكل': 61,
#          'البيتزا': 1,
#          'طبق': 9,
#          'الصفيح': 1,
#          'أشخاص': 307,
#          'قمة': 120,
#          'تطل': 31,
#          'واد': 10,
#          'أخضر': 183,
#          'يطلون': 1,
#          'الوادي': 12,
#          'يرتاحون': 2,
#          'الجبال': 129,
#          'يشاهد': 104,
#          'القوارب': 18,
#          'درابزين': 26,
#          'الى': 36,
#          'العديد': 159,
#          'والطوافات': 1,
#          'يطل': 38,
#          'حشد': 268,
#          'المطاطية': 2,
#          'يمثلان': 3,
#          'للكاميرا': 53,
#          'آخر': 399,
#          'يد': 56,
#          'زوجين': 26,
#          'متعددي': 1,
#          'الأعراق': 1,
#          'لصورة': 25,
#          'الأرض': 215,
#          'ويأكل': 3,
#          'التلفزيون': 8,
#          'تلفزيون': 3,
#          'صورة': 279,
#          'لفتاة': 20,
#          'عليه': 47,
#          'ما': 150,
#          'لتناول': 6,
#          'الطعام': 52,
#          'بضعة': 1,
#          'يجلسون': 193,
#          'يقوم': 494,
#          'الطفل': 167,
#          'بأداء': 23,
#          'خدعة': 88,
#          'لوح': 404,
#          'التزلج': 302,
#          'يميل': 35,
#          'تزلج': 198,
#          'الحائط': 22,
#          'بعمل': 82,
#          'يراقبه': 10,
#          'الواح': 1,
#          'تتجول': 4,
#          'نهر': 50,
#          'تجدف': 7,
#          'قارب': 144,
#          'أسفل': 274,
#          'النهر': 115,
#          'مجداف': 7,
#          'الأمواج': 225,
#          'المحيط': 265,
#          'يتعاركون': 1,
#          'بالوسادات': 3,
#          'الصغار': 102,
#          'أربعة': 236,
#          'يواجهون': 4,
#          'معركة': 2,
#          'عمال': 5,
#          'البناء': 10,
#          'يأخذون': 9,
#          'استراحة': 5,
#          'اثنان': 52,
#          'جانب': 94,
#          'يأخذان': 8,
#          'صبيان': 111,
#          'بركة': 362,
#          'طفلين': 85,
#          'يركضان': 130,
#          'ويلعبان': 6,
#          'بعض': 282,
#          'شقراء': 80,
#          'تنتظر': 24,
#          'رحلة': 14,
#          'تشير': 19,
#          'سيارة': 294,
#          'أجرة': 1,
#          'المرأة': 106,
#          'الثوب': 5,
#          'الأزرق': 160,
#          'تمد': 4,
#          'بذراعها': 1,
#          'لحركة': 1,
#          'المرور': 16,
#          'القادمة': 3,
#          'تنظر': 86,
#          'كتيب': 2,
#          'ركوب': 105,
#          'القطار': 40,
#          'قطار': 30,
#          'تقرأ': 16,
#          'كتابا': 16,
#          'وتنظر': 13,
#          'شاطئ': 117,
#          'الأسود': 193,
#          'ينزل': 44,
#          'الغطس': 1,
#          'العالي': 10,
#          'غوص': 2,
#          'عالية': 49,
#          'البركة': 47,
#          'اللوح': 7,
#          'نافذة': 54,
#          'يخلع': 2,
#          'قميصه': 11,
#          'بمصعد': 1,
#          'ورأسه': 1,
#          'مصعد': 13,
#          'خفيف': 6,
#          'ملابس': 336,
#          'السباحة': 232,
#          'الولد': 45,
#          'مسافر': 28,
#          'أدناه': 6,
#          'المتزحلق': 52,
#          'الجبل': 104,
#          'المغطى': 11,
#          'بالثلوج': 72,
#          'متزحلق': 13,
#          'جبل': 170,
#          'وراء': 60,
#          'الفريسبي': 47,
#          'سراويل': 21,
#          'منتصف': 46,
#          'أثناء': 223,
#          'حركة': 30,
#          'الكثيفة': 1,
#          'وسط': 67,
#          'مزدحم': 68,
#          'الرمل': 14,
#          'اخر': 5,
#          'تجري': 36,
#          'الرمال': 224,
#          'وكرة': 9,
#          'تنس': 59,
#          'كائن': 11,
#          'بالونات': 9,
#          'الليل': 67,
#          'الساخن': 5,
#          'أضاءت': 1,
#          'يشاهدون': 49,
#          'خوذة': 161,
#          'يركب': 646,
#          'دراجة': 698,
#          'الصغير': 116,
#          'دراجته': 174,
#          'سباق': 194,
#          'تجمع': 46,
#          'الظلام': 14,
#          'حول': 218,
#          'طاولة': 129,
#          'الشرفة': 8,
#          'وشورت': 18,
#          'غامق': 12,
#          'كلبين': 44,
#          'ينظف': 1,
#          'الفقاعات': 13,
#          'وجهه': 53,
#          'بالفقاعات': 6,
#          'تنظيف': 2,
#          'بالماء': 46,
#          'والصابون': 1,
#          'ينزلق': 134,
#          'شورت': 32,
#          'حوض': 44,
#          'الفناء': 101,
#          'الخلفي': 40,
#          'الشلال': 4,
#          'يرمي': 65,
#          'وينتظر': 3,
#          'أن': 74,
#          'حتى': 7,
#          'يتمكن': 3,
#          'الإمساك': 4,
#          'به': 90,
#          'يخرج': 60,
#          'لسانه': 29,
#          'أجل': 36,
#          'الكاميرا': 236,
#          'يصنعان': 4,
#          'وجوه': 10,
#          'مضحكة': 15,
#          'الأولاد': 124,
#          'ينظرون': 50,
#          'يلقي': 23,
#          'أحدهم': 18,
#          'حصان': 81,
#          'أشقر': 72,
#          'وفتاة': 119,
#          'نار': 18,
#          'برميل': 9,
#          'وحصانها': 1,
#          'تقف': 388,
#          'النار': 51,
#          'وحصانان': 1,
#          'يشاهدان': 17,
#          'نحيف': 4,
#          'أصغر': 43,
#          'حجما': 1,
#          'يحدق': 31,
#          'وسطهم': 1,
#          'أحجام': 2,
#          'مختلفة': 23,
#          'سيدة': 95,
#          'بدون': 21,
#          'منصة': 37,
#          'ملقى': 3,
#          'أبيضيضع': 1,
#          'الطوب': 45,
#          'وقميص': 48,
#          'مكان': 57,
#          'مغلق': 5,
#          'الفتاة': 148,
#          'الحزام': 3,
#          'وتتسلق': 2,
#          'قابل': 12,
#          'للنفخ': 25,
#          'صغيرين': 13,
#          'مضخمة': 1,
#          'عائلة': 40,
#          'جرار': 5,
#          'يوم': 73,
#          'جميل': 22,
#          'يركبون': 90,
#          'بسيارة': 2,
#          'الطلق': 141,
#          'زي': 210,
#          'أحمر': 452,
#          'ترتدي': 603,
#          'الزي': 182,
#          'شخصين': 50,
#          'آخرين': 47,
#          'شابة': 112,
#          'وريشة': 1,
#          'يتزلجان': 8,
#          'منطقة': 190,
#          'حرجية': 10,
#          'يرتديان': 183,
#          'يشقون': 2,
#          'طريقهم': 3,
#          'الغابات': 23,
#          'وحيد': 27,
#          'يشق': 7,
#          'طريقه': 8,
#          'بالثلج': 44,
#          'يتسلقان': 16,
#          'يهرول': 14,
#          'طريق': 201,
#          'ممهد': 2,
#          'الأم': 12,
#          'والطفل': 8,
#          'يصطادان': 7,
#          'الممر': 17,
#          'ممشى': 13,
#          'البحر': 26,
#          'يصطادون': 1,
#          'المساء': 5,
#          'وجينز': 22,
#          'تركب': 90,
#          'وجبل': 3,
#          'الخيل': 30,
#          'فصل': 18,
#          'الشتاء': 31,
#          'الخيول': 41,
#          'تسحب': 25,
#          'يسحبان': 7,
#          'خيلان': 1,
#          'زلاجة': 50,
#          'باستخدام': 21,
#          'مستوي': 1,
#          'بحبل': 33,
#          'أمان': 4,
#          'يصعد': 39,
#          'داخل': 93,
#          'قبة': 1,
#          'صخرية': 45,
#          'كهف': 8,
#          'متسلقي': 10,
#          'الكبيرة': 51,
#          'الرحالة': 2,
#          'تكمن': 5,
#          'الجافة': 6,
#          'المتنزهين': 14,
#          'يستريحون': 4,
#          'يستريح': 12,
#          'معداتهم': 3,
#          'طباشيرية': 1,
#          'لطفلين': 1,
#          'رسم': 8,
#          'الطباشير': 4,
#          'فستان': 37,
#          'ترسم': 8,
#          'لصبي': 8,
#          'كومة': 46,
#          'العميقة': 14,
#          'نافورة': 97,
#          'نفق': 43,
#          'خارجا': 55,
#          'النفق': 3,
#          'مسار': 182,
#          'عقبة': 79,
#          'يركضون': 47,
#          'الأوساخ': 35,
#          'كلبان': 304,
#          'تمشي': 127,
#          'رملي': 30,
#          'تطفو': 11,
#          'يشرب': 46,
#          'يسبح': 166,
#          'بندقية': 9,
#          'سروال': 59,
#          'برتقالي': 98,
#          'بلعبته': 3,
#          'الجديدة': 1,
#          'والأصفر': 17,
#          'منحدر': 244,
#          'وحيدا': 5,
#          'الجرف': 9,
#          'القفزة': 6,
#          'تطير': 23,
#          'عربات': 17,
#          'الثلوج': 20,
#          'ناس': 5,
#          'بخوذات': 1,
#          'واقية': 37,
#          'واثنين': 20,
#          'يقودون': 6,
#          'مركبات': 4,
#          'رباعية': 18,
#          'الدفع': 14,
#          'مركبة': 26,
#          'بأربع': 3,
#          'دواليب': 1,
#          'تقفز': 166,
#          'فارغ': 13,
#          'عجلات': 23,
#          'يحلق': 17,
#          'بمركبة': 1,
#          'أربع': 53,
#          'مقلم': 39,
#          'ماء': 71,
#          'سعيد': 8,
#          'قدم': 232,
#          'يمشي': 327,
#          'القدم': 431,
#          'السياج': 49,
#          'يرسم': 10,
#          'فنان': 6,
#          'السحب': 3,
#          'قماش': 18,
#          'يقود': 76,
#          'راكب': 250,
#          'الدراجة': 251,
#          'جبلية': 25,
#          'اعلى': 2,
#          'التلة': 5,
#          'النارية': 119,
#          'لعبته': 9,
#          'الحبلية': 1,
#          'ساحة': 70,
#          'تمسك': 46,
#          'بكاميرا': 11,
#          'سينمائية': 1,
#          'تبحث': 20,
#          'كاميرا': 65,
#          'فيديو': 23,
#          'قديمة': 19,
#          'الطراز': 6,
#          'سلاح': 1,
#          'وبني': 107,
#          'بالفريسبي': 3,
#          'يلتقط': 26,
#          'رشيق': 1,
#          'المتفرجين': 26,
#          'كثب': 1,
#          'يرص': 1,
#          'يلبس': 32,
#          'قميصا': 200,
#          'مخططا': 10,
#          'ويمسك': 22,
#          'بتسلق': 3,
#          'وسروال': 14,
#          'أرجواني': 36,
#          'ينبوع': 2,
#          'يرش': 57,
#          'الطفلة': 26,
#          'عامة': 9,
#          'عصفور': 2,
#          'طائر': 103,
#          'يتشبث': 5,
#          'الطائر': 154,
#          'بإصبع': 1,
#          'أسمر': 134,
#          'يجري': 98,
#          'بسرعة': 42,
#          'يضحك': 27,
#          'مرعب': 2,
#          'بيج': 8,
#          'تسبح': 29,
#          'مبتسمة': 38,
#          'مسبح': 3,
#          'رأسها': 44,
#          'مقلوبة': 5,
#          'السرير': 45,
#          'لوحه': 31,
#          'يتجول': 39,
#          'دراجات': 39,
#          'الدراجات': 138,
#          'يتبعون': 5,
#          'درب': 68,
#          'الجاف': 16,
#          'الترابية': 68,
#          'علم': 15,
#          'قمر': 1,
#          'ونجم': 1,
#          'يلوح': 10,
#          'بعلم': 2,
#          'مسلم': 1,
#          'تساعده': 1,
#          'السيدة': 17,
#          'رفع': 10,
#          'العلم': 27,
#          'نصف': 6,
#          'عاري': 10,
#          'كرسيه': 1,
#          'مسن': 50,
#          'ويرتاح': 1,
#          'يسترخي': 1,
#          'كرسي': 87,
#          'للطي': 6,
#          'تسترد': 2,
#          'أفواههما': 5,
#          'شباب': 8,
#          'يحتفلون': 2,
#          'الشوارع': 62,
#          'ثلاث': 155,
#          'نساء': 96,
#          'يشربن': 1,
#          'ويتظاهرن': 1,
#          'شابات': 5,
#          'يمتثلن': 1,
#          'موكب': 35,
#          'التنس': 187,
#          'البني': 256,
#          'الفم': 9,
#          'البنية': 37,
#          'تركض': 170,
#          'بنيتين': 1,
#          'تمر': 33,
#          'الأعشاب': 16,
#          'البحرية': 9,
#          'يعمل': 43,
#          'الصنادل': 3,
#          'ويبحثان': 2,
#          'حقائب': 29,
#          'الظهر': 24,
#          'ينظران': 64,
#          'كبيران': 13,
#          'يحملان': 48,
#          'محطة': 26,
#          'للحافلات': 3,
#          'سرير': 36,
#          'الفراش': 2,
#          'غرفة': 67,
#          'النوم': 4,
#          'يرتاح': 5,
#          'المتزلج': 103,
#          'المتزلجون': 5,
#          'جالسين': 8,
#          'المنحدرات': 21,
#          'تلبس': 10,
#          'تسير': 140,
#          'المدينة': 145,
#          'رصيف': 130,
#          'المتاجر': 6,
#          'ويحمل': 41,
#          'حذاءه': 2,
#          'السيارة': 28,
#          'و': 356,
#          'حذاء': 35,
#          'يعبران': 3,
#          'جسر': 65,
#          'يسيران': 104,
#          'معلق': 33,
#          'بيئة': 7,
#          'استوائية': 1,
#          'تجمعوا': 7,
#          'مطلية': 6,
#          'تخرج': 14,
#          'شاحنة': 46,
#          'يشاهدها': 5,
#          'الآخرون': 51,
#          'امرأتان': 167,
#          'وأربعة': 5,
#          'يقفون': 215,
#          'بألوان': 15,
#          'زاهية': 40,
#          'تمتثل': 1,
#          'تحمل': 280,
#          'خنزير': 5,
#          'تعانق': 17,
#          'شوارع': 29,
#          'دراجتها': 22,
#          'يعبر': 18,
#          'لعبور': 5,
#          'وحقيبة': 21,
#          'ظهر': 92,
#          'مرتدية': 14,
#          'وشورتا': 5,
#          'سماعات': 23,
#          'الرأس': 29,
#          'وقميصا': 25,
#          'تهرول': 8,
#          'راكبو': 10,
#          'عند': 87,
#          'تقاطع': 7,
#          'انتظار': 29,
#          'التقاطع': 1,
#          'سائقون': 1,
#          'يرافق': 1,
#          'يسحب': 40,
#          'تجرها': 3,
#          'يضرب': 52,
#          'الكرة': 362,
#          'الشباك': 7,
#          'البيسبول': 149,
#          'شبكة': 18,
#          'داخلها': 1,
#          'الضحلة': 52,
#          'الصغيرة': 81,
#          'البوق': 5,
#          'فرقة': 23,
#          'موسيقية': 18,
#          'مراهقة': 8,
#          'آسيوية': 28,
#          'خضراء': 190,
#          'تقدم': 9,
#          'المشروبات': 12,
#          'صينية': 5,
#          'باريستا': 1,
#          'ستاربكس': 1,
#          'النادلة': 2,
#          'الشاي': 3,
#          'المجاني': 3,
#          'للرواد': 1,
#          'رجال': 177,
#          'بإعداد': 7,
#          'سهل': 14,
#          'يحملون': 63,
#          'المواد': 4,
#          'مزلقة': 9,
#          'اشخاص': 22,
#          'وزلاجة': 1,
#          'الرياضي': 8,
#          'أحذية': 13,
#          'رياضية': 32,
#          'القش': 28,
#          'عجوز': 49,
#          'فتيات': 79,
#          'حاجز': 55,
#          'تحيط': 26,
#          'يمشون': 61,
#          'خلال': 321,
#          'نبات': 3,
#          'يغطي': 15,
#          'بهو': 1,
#          'المدخل': 9,
#          'فاتحة': 5,
#          'وزحافات': 1,
#          'قرب': 52,
#          'والجليد': 4,
#          'مقنع': 3,
#          'يتصارعان': 39,
#          'يعض': 59,
#          'أحدهما': 57,
#          'الآخر': 43,
#          'تتصارع': 8,
#          'يعطي': 14,
#          'ألعاب': 29,
#          'لكلب': 11,
#          'شد': 22,
#          'بطانية': 36,
#          'حلقة': 15,
#          'الأنف': 8,
#          'سن': 24,
#          'المراهقة': 23,
#          'خاتم': 1,
#          'فضي': 4,
#          'بارز': 1,
#          'أنفه': 19,
#          'مقربة': 27,
#          'لرجل': 30,
#          'بحلقة': 8,
#          'أنف': 9,
#          'الأصفر': 80,
#          'نظرة': 7,
#          'دراماتيكية': 1,
#          'الفيديو': 5,
#          'حانة': 17,
#          'آلات': 10,
#          'لألعاب': 1,
#          'بنيان': 40,
#          'جنب': 32,
#          'ذات': 189,
#          'شعر': 169,
#          'يسيرون': 101,
#          'الطقس': 4,
#          'الحار': 1,
#          'مشغول': 2,
#          'وقت': 4,
#          'الصيف': 4,
#          'والأسود': 60,
#          'يرشان': 5,
#          'ببعض': 11,
#          'طفلان': 229,
#          'الجينز': 55,
#          'بعضهم': 63,
#          'الصبية': 14,
#          'يدفع': 48,
#          'الآباء': 4,
#          'سيارات': 15,
#          'دفعهما': 1,
#          'شكل': 18,
#          'فريق': 56,
#          'يرتدون': 230,
#          'زيهم': 1,
#          'الرسمي': 21,
#          'قبعات': 22,
#          'دولفين': 3,
#          'نفس': 16,
#          'والزهور': 7,
#          'باللونين': 34,
#          'أشعث': 12,
#          'بعصا': 80,
#          'باتجاه': 38,
#          'حمام': 85,
#          'إعلان': 10,
#          'عبور': 18,
#          'مضاء': 10,
#          'مترو': 31,
#          'الأنفاق': 22,
#          'رتركب': 1,
#          'الهوائية': 27,
#          'الأحادية': 10,
#          'العجلة': 13,
#          'هناك': 178,
#          'وطفل': 53,
#          'بخارية': 26,
#          'يقرأ': 35,
#          'نزهة': 19,
#          'تتناول': 4,
#          'يأكلون': 9,
#          'الخضراء': 49,
#          'يمشيان': 38,
#          'زهريا': 3,
#          'ومحفظة': 4,
#          'ورجلا': 1,
#          'يستلقي': 44,
#          'تتقاتل': 14,
#          'برتقال': 2,
#          'الطويل': 58,
#          'يمتثل': 7,
#          'وفي': 4,
#          'الخلفية': 215,
#          'يتعلق': 5,
#          'غريب': 10,
#          'يحيط': 11,
#          'بها': 38,
#          'سوداء': 320,
#          'يأخذ': 87,
#          'الكنيسة': 7,
#          'الأسرة': 2,
#          'إحدى': 13,
#          'المحاط': 2,
#          'بأشجار': 8,
#          'جميلة': 12,
#          'تحاول': 29,
#          'الصخرة': 16,
#          'القارب': 22,
#          'البارجة': 1,
#          'وأحمر': 11,
#          'يضحكان': 11,
#          'فتاتان': 221,
#          'تضحكان': 6,
#          'فتاتين': 43,
#          'صغيرتين': 4,
#          'تلعبان': 39,
#          'الأرجوحة': 72,
#          'فتى': 68,
#          'أرجوحة': 102,
#          'بملعقة': 2,
#          'ملعقة': 4,
#          'لوحدها': 4,
#          'أعشاب': 4,
#          'ضارة': 2,
#          'نحاسي': 1,
#          'الملابس': 51,
#          'الرمادية': 24,
#          'وسادة': 12,
#          'يرقد': 24,
#          'أريكة': 48,
#          'ومصاصة': 1,
#          'يمص': 4,
#          'مصاصة': 11,
#          'تعلب': 1,
#          'ملعب': 146,
#          ...})

# %%
vocabulary
# Out:
# ['طفلة',
#  'صغيرة',
#  'تتسلق',
#  'إلى',
#  'مسرح',
#  'خشبي',
#  'طفلة',
#  'صغيرة',
#  'تتسلق',
#  'الدرج',
#  'إلى',
#  'منزلها',
#  'فتاة',
#  'صغيرة',
#  'في',
#  'ثوب',
#  'وردي',
#  'تذهب',
#  'إلى',
#  'المقصورة',
#  'الخشبية',
#  'كلب',
#  'أسود',
#  'وكلب',
#  'ثلاثي',
#  'الألوان',
#  'يلعبان',
#  'مع',
#  'بعضهما',
#  'البعض',
#  'على',
#  'الطريق',
#  'كلب',
#  'أسود',
#  'وكلب',
#  'أبيض',
#  'ببقع',
#  'بنية',
#  'يحدقان',
#  'في',
#  'بعضهما',
#  'البعض',
#  'في',
#  'الشارع',
#  'كلاب',
#  'على',
#  'الرصيف',
#  'تتحرك',
#  'نحو',
#  'بعضها',
#  'البعض',
#  'فتاة',
#  'صغيرة',
#  'مغطاة',
#  'بالطلاء',
#  'تجلس',
#  'أمام',
#  'قوس',
#  'قزح',
#  'فتاة',
#  'صغيرة',
#  'تجلس',
#  'أمام',
#  'قوس',
#  'قزح',
#  'ملون',
#  'كبير',
#  'فتاة',
#  'أمام',
#  'لوحة',
#  'قوس',
#  'قزح',
#  'رجل',
#  'يجلس',
#  'على',
#  'مقعد',
#  'بينما',
#  'يجلس',
#  'كلبه',
#  'بجانبه',
#  'رجل',
#  'ينام',
#  'على',
#  'مقعد',
#  'في',
#  'الخارج',
#  'مع',
#  'كلب',
#  'أبيض',
#  'وأسود',
#  'يجلس',
#  'بجانبه',
#  'رجل',
#  'بلا',
#  'قميص',
#  'يجلس',
#  'على',
#  'مقعد',
#  'في',
#  'الحديقة',
#  'مع',
#  'كلبه',
#  'رجل',
#  'يرتدي',
#  'قبعة',
#  'برتقالية',
#  'رجل',
#  'يرتدي',
#  'قبعة',
#  'برتقالية',
#  'ونظارات',
#  'الرجل',
#  'ذو',
#  'الأذن',
#  'المثقوبة',
#  'يرتدي',
#  'نظارات',
#  'وقبعة',
#  'برتقالية',
#  'اللون',
#  'طفل',
#  'يلعب',
#  'على',
#  'حبل',
#  'فتاة',
#  'صغيرة',
#  'تتسلق',
#  'على',
#  'الحبل',
#  'الأحمر',
#  'طفل',
#  'صغير',
#  'يمسك',
#  'بالحبال',
#  'الحمراء',
#  'في',
#  'الملعب',
#  'كلب',
#  'أبيض',
#  'وأسود',
#  'يركض',
#  'في',
#  'حديقة',
#  'عشبية',
#  'محاطة',
#  'بسياج',
#  'أبيض',
#  'كلب',
#  'أبيض',
#  'وأسود',
#  'يركض',
#  'على',
#  'العشب',
#  'كلب',
#  'يمتد',
#  'على',
#  'العشب',
#  'الأخضر',
#  'بالقرب',
#  'من',
#  'سياج',
#  'خشبي',
#  'كلب',
#  'يهز',
#  'رأسه',
#  'بالقرب',
#  'من',
#  'الشاطئ',
#  'كرة',
#  'حمراء',
#  'بجانبه',
#  'كلب',
#  'أبيض',
#  'يهتز',
#  'على',
#  'حافة',
#  'الشاطئ',
#  'مع',
#  'كرة',
#  'برتقالية',
#  'كلب',
#  'أبيض',
#  'يلعب',
#  'مع',
#  'كرة',
#  'حمراء',
#  'على',
#  'الشاطئ',
#  'بالقرب',
#  'من',
#  'الماء',
#  'صبي',
#  'يبتسم',
#  'أمام',
#  'حائط',
#  'صخري',
#  'في',
#  'مدينة',
#  'صبي',
#  'صغير',
#  'يركض',
#  'على',
#  'الشارع',
#  'طفل',
#  'صغير',
#  'يسير',
#  'في',
#  'شارع',
#  'مرصوف',
#  'بالحجارة',
#  'مع',
#  'عمود',
#  'معدني',
#  'ورجل',
#  'خلفه',
#  'كلب',
#  'أسود',
#  'يقفز',
#  'فوق',
#  'الجذع',
#  'كلب',
#  'رمادي',
#  'يقفز',
#  'فوق',
#  'شجرة',
#  'ساقطة',
#  'كلب',
#  'أسود',
#  'كبير',
#  'يقفز',
#  'فوق',
#  'جذع',
#  'كلب',
#  'أبيض',
#  'وأبيض',
#  'يمر',
#  'عبر',
#  'الثلج',
#  'كلب',
#  'يركض',
#  'في',
#  'الثلج',
#  'كلب',
#  'يمر',
#  'عبر',
#  'الثلج',
#  'رجل',
#  'في',
#  'القبعة',
#  'يعرض',
#  'صور',
#  'ا',
#  'بجوار',
#  'أحد',
#  'المتزلجين',
#  'في',
#  'قبعة',
#  'زرقاء',
#  'متسابق',
#  'ينظر',
#  'إلى',
#  'الصور',
#  'المؤطرة',
#  'في',
#  'الثلج',
#  'بجوار',
#  'الأشجار',
#  'رجل',
#  'على',
#  'الزلاجات',
#  'يبحث',
#  'عن',
#  'عمل',
#  'فني',
#  'للبيع',
#  'في',
#  'الثلج',
#  'صور',
#  'لشخص',
#  'واحد',
#  'يتسلق',
#  'جرف',
#  'ا',
#  'مجموعة',
#  'من',
#  'الناس',
#  'تتسلق',
#  'الصخور',
#  'على',
#  'جدار',
#  'تسلق',
#  'الصخور',
#  'مجموعة',
#  'من',
#  'الناس',
#  'يتسلقون',
#  'صخرة',
#  'كلب',
#  'بني',
#  'يطارد',
#  'الماء',
#  'على',
#  'العشب',
#  'كلب',
#  'بني',
#  'يلعب',
#  'مع',
#  'الخرطوم',
#  'كلب',
#  'بني',
#  'يركض',
#  'في',
#  'حديقة',
#  'بالقرب',
#  'من',
#  'خرطوم',
#  'الحديقة',
#  'كلب',
#  'يستعد',
#  'للقبض',
#  'على',
#  'جسم',
#  'في',
#  'حقل',
#  'مع',
#  'السيارات',
#  'القريبة',
#  'كلب',
#  'أبيض',
#  'جاهز',
#  'للقبض',
#  'على',
#  'كرة',
#  'صفراء',
#  'تحلق',
#  'في',
#  'الهواء',
#  'كلب',
#  'أبيض',
#  'يركض',
#  'خلف',
#  'كرة',
#  'صفراء',
#  'كلب',
#  'أبيض',
#  'وأسود',
#  'يقفز',
#  'في',
#  'الهواء',
#  'للحصول',
#  'على',
#  'لعبة',
#  'كلب',
#  'أبيض',
#  'وأسود',
#  'يقفز',
#  'نحو',
#  'لعبة',
#  'صفراء',
#  'يحاول',
#  'كلب',
#  'أبيض',
#  'التقاط',
#  'كرة',
#  'في',
#  'الجو',
#  'فوق',
#  'حقل',
#  'عشبي',
#  'طفل',
#  'وامرأة',
#  'على',
#  'حافة',
#  'المياه',
#  'في',
#  'مدينة',
#  'كبيرة',
#  'صبي',
#  'صغير',
#  'على',
#  'بحيرة',
#  'يراقب',
#  'بطة',
#  'شخصان',
#  'على',
#  'حافة',
#  'بحيرة',
#  'زوجان',
#  'يجلسان',
#  'على',
#  'العشب',
#  'مع',
#  'رضيع',
#  'وعربة',
#  'أطفال',
#  'زوجان',
#  'مع',
#  'طفلهما',
#  'المولود',
#  'حديث',
#  'ا',
#  'يجلسان',
#  'تحت',
#  'شجرة',
#  'تواجه',
#  'بحيرة',
#  'زوجان',
#  'مع',
#  'طفل',
#  'بجانب',
#  'عربة',
#  'الأطفال',
#  'كلب',
#  'يقفز',
#  'في',
#  'الماء',
#  'الكلب',
#  'الاسود',
#  'يمر',
#  'عبر',
#  'الماء',
#  'كلب',
#  'أسود',
#  'يرشش',
#  'في',
#  'الماء',
#  'رجل',
#  'يحفر',
#  'حفرة',
#  'في',
#  'الجليد',
#  'شخص',
#  'في',
#  'الثلج',
#  'يحفر',
#  'حفرة',
#  'في',
#  'الجليد',
#  'شخص',
#  'يقف',
#  'على',
#  'بحيرة',
#  'متجمدة',
#  'كلاب',
#  'بيضاء',
#  'تلعب',
#  'على',
#  'الشاطئ',
#  'اثنين',
#  'من',
#  'الكلاب',
#  'يلعبون',
#  'معا',
#  'على',
#  'الشاطئ',
#  'اثنين',
#  'من',
#  'الكلاب',
#  'تلعب',
#  'على',
#  'طول',
#  'الشاطئ',
#  'الرملي',
#  'رجل',
#  'يتسلق',
#  'الجليد',
#  'متسلق',
#  'الجليد',
#  'في',
#  'سترة',
#  'زرقاء',
#  'والسراويل',
#  'السوداء',
#  'متسلق',
#  'يتسلق',
#  'جدار',
#  'الجليد',
#  'كلب',
#  'أسود',
#  'يحمل',
#  'شيئ',
#  'ا',
#  'على',
#  'العشب',
#  'كلب',
#  'أسود',
#  'لديه',
#  'لعبة',
#  'زرقاء',
#  'في',
#  'فمه',
#  'كلب',
#  'في',
#  'العشب',
#  'مع',
#  'شيء',
#  'أزرق',
#  'في',
#  'فمه',
#  'رجل',
#  'ورضيع',
#  'في',
#  'قوارب',
#  'الكاياك',
#  'الصفراء',
#  'على',
#  'الماء',
#  'رجل',
#  'وولد',
#  'صغير',
#  'في',
#  'سترات',
#  'النجاة',
#  'الزرقاء',
#  'يجذفون',
#  'زورق',
#  'أصفر',
#  'رجل',
#  'وصبي',
#  'صغير',
#  'يركبان',
#  'في',
#  'زورق',
#  'أصفر',
#  'كلب',
#  'أسود',
#  'وكلب',
#  'بني',
#  'يقفزان',
#  'للقبض',
#  'على',
#  'لعبة',
#  'حمراء',
#  'كلب',
#  'أسود',
#  'وكلب',
#  'بني',
#  'يلعبان',
#  'بلعبة',
#  'حمراء',
#  'في',
#  'فناء',
#  'كلب',
#  'أسود',
#  'ينقض',
#  'على',
#  'الجسم',
#  'الأحمر',
#  'طفل',
#  'يرتدي',
#  'سترة',
#  'حمراء',
#  'يلعب',
#  'هوكي',
#  'طفل',
#  'صغير',
#  'يلعب',
#  'حارس',
#  'المرمى',
#  'في',
#  'حلبة',
#  'الهوكي',
#  'شاب',
#  'راكع',
#  'أمام',
#  'هدف',
#  'الهوكي',
#  'مع',
#  'عصا',
#  'هوكي',
#  'في',
#  'يده',
#  'اليمنى',
#  'رجل',
#  'يجلس',
#  'ويقرأ',
#  'صحيفة',
#  'رجل',
#  'يجلس',
#  'بالقرب',
#  'من',
#  'تمثال',
#  'كبير',
#  'رجل',
#  'يجلس',
#  'أمام',
#  'تمثال',
#  'معدني',
#  'أمام',
#  'مبنى',
#  'يتم',
#  'وضع',
#  'خيمة',
#  'على',
#  'الجليد',
#  'رجلان',
#  'يقفان',
#  'على',
#  'جليد',
#  'يبحثان',
#  'في',
#  'شيء',
#  'مغطى',
#  'بقماش',
#  'أزرق',
#  'شخصان',
#  'يقفان',
#  'خارج',
#  'هيكل',
#  'خيمة',
#  'زرقاء',
#  'على',
#  'سطح',
#  'ثلجي',
#  'امرأة',
#  'تجثم',
#  'بالقرب',
#  'من',
#  'ثلاثة',
#  'كلاب',
#  'في',
#  'حقل',
#  'يقف',
#  'ثلاثة',
#  'كلاب',
#  'في',
#  'العشب',
#  'ويجلس',
#  'الشخص',
#  'بجانبهم',
#  'ثلاثة',
#  'كلاب',
#  'على',
#  'تلة',
#  'عشبية',
#  'رجل',
#  'يقف',
#  'أمام',
#  'ناطحة',
#  'سحاب',
#  'رجل',
#  'يقف',
#  'أمام',
#  'ناطحة',
#  'سحاب',
#  'رجل',
#  'يقف',
#  'أمام',
#  'مبنى',
#  'طويل',
#  'للغاية',
#  'طفل',
#  'يقضم',
#  'سلعة',
#  'مخبوزة',
#  'صبي',
#  'صغير',
#  'يضع',
#  'شيئ',
#  'ا',
#  'في',
#  'فمه',
#  'بكلتا',
#  'يديه',
#  'الصبي',
#  'يأكل',
#  'البيتزا',
#  'على',
#  'طبق',
#  'من',
#  'الصفيح',
#  'ثلاثة',
#  'أشخاص',
#  'على',
#  'قمة',
#  'تطل',
#  'على',
#  'واد',
#  'أخضر',
#  'ثلاثة',
#  'أشخاص',
#  'يطلون',
#  'على',
#  'الوادي',
#  'الأخضر',
#  'ثلاثة',
#  'أشخاص',
#  'يرتاحون',
#  'على',
#  'حافة',
#  'فوق',
#  'الجبال',
#  'صبي',
#  'في',
#  'قميص',
#  'أخضر',
#  'يشاهد',
#  'القوارب',
#  'صبي',
#  'ينظر',
#  'على',
#  'درابزين',
#  'ينظر',
#  'الى',
#  'العديد',
#  'من',
#  'القوارب',
#  'والطوافات',
#  'في',
#  'الماء',
#  'صبي',
#  'صغير',
#  'يطل',
#  'على',
#  'حشد',
#  'من',
#  'القوارب',
#  'المطاطية',
#  'رجل',
#  'وامرأة',
#  'يمثلان',
#  'للكاميرا',
#  'بينما',
#  'ينظر',
#  'رجل',
#  'آخر',
#  'رجل',
#  'يمسك',
#  'يد',
#  'امرأة',
#  'زوجين',
#  'متعددي',
#  'الأعراق',
#  'يمثلان',
#  'لصورة',
#  'شخص',
#  'يجلس',
#  'على',
#  'الأرض',
#  'ويأكل',
#  'أمام',
#  'التلفزيون',
#  'تلفزيون',
#  'مع',
#  'صورة',
#  'لفتاة',
#  'عليه',
#  'شخص',
#  'ما',
#  'يجلس',
#  'أمام',
#  'التلفزيون',
#  'لتناول',
#  'الطعام',
#  'بضعة',
#  'أشخاص',
#  'يجلسون',
#  'على',
#  'حافة',
#  'تطل',
#  'على',
#  'الشاطئ',
#  'مجموعة',
#  'من',
#  'الناس',
#  'يجلسون',
#  'على',
#  'جدار',
#  'على',
#  'الشاطئ',
#  'حشد',
#  'من',
#  'الناس',
#  'على',
#  'الشاطئ',
#  'يقوم',
#  'الطفل',
#  'بأداء',
#  'خدعة',
#  'لوح',
#  'التزلج',
#  'بينما',
#  'يميل',
#  'طفل',
#  'آخر',
#  'يحمل',
#  'لوح',
#  'تزلج',
#  'على',
#  'الحائط',
#  'يقوم',
#  'صبي',
#  'صغير',
#  'بعمل',
#  'خدعة',
#  'على',
#  'لوح',
#  'تزلج',
#  'بينما',
#  'يراقبه',
#  'شاب',
#  'آخر',
#  'اثنين',
#  'على',
#  'الواح',
#  'تزلج',
#  'فتاة',
#  'تتجول',
#  'في',
#  'نهر',
#  'كبير',
#  'امرأة',
#  'تجدف',
#  'على',
#  'قارب',
#  'أسفل',
#  'النهر',
#  'امرأة',
#  'مع',
#  'مجداف',
#  'فتاة',
#  'تلعب',
#  'في',
#  'الأمواج',
#  'تلعب',
#  'فتاة',
#  'في',
#  'المحيط',
#  'على',
#  'الشاطئ',
#  'فتاة',
#  'تلعب',
#  'في',
#  'الماء',
#  'مجموعة',
#  'من',
#  'الأطفال',
#  'يتعاركون',
#  'بالوسادات',
#  'مجموعة',
#  'من',
#  'الأطفال',
#  'الصغار',
#  'يلعبون',
#  'بالوسادات',
#  'أربعة',
#  'أطفال',
#  'يواجهون',
#  'معركة',
#  'بالوسادات',
#  'اثنين',
#  'من',
#  'عمال',
#  'البناء',
#  'يأخذون',
#  'استراحة',
#  'يجلس',
#  'اثنان',
#  'من',
#  'عمال',
#  'البناء',
#  'على',
#  'جانب',
#  'مبنى',
#  'رجلان',
#  'يأخذان',
#  'استراحة',
#  'من',
#  'البناء',
#  'يلعب',
#  'الأطفال',
#  'في',
#  'الماء',
#  'صبيان',
#  'يلعبان',
#  'في',
#  'بركة',
#  'طفلين',
#  'يركضان',
#  'ويلعبان',
#  'في',
#  'بعض',
#  'الماء',
#  'امرأة',
#  'شقراء',
#  'في',
#  'قميص',
#  'أزرق',
#  'تنتظر',
#  'رحلة',
#  'امرأة',
#  'شقراء',
#  'في',
#  'الشارع',
#  'تشير',
#  'الى',
#  'سيارة',
#  'أجرة',
#  'المرأة',
#  'في',
#  'الثوب',
#  'الأزرق',
#  'تمد',
#  'بذراعها',
#  'لحركة',
#  'المرور',
#  'القادمة',
#  'فتاة',
#  'صغيرة',
#  'تنظر',
#  'في',
#  'كتيب',
#  'عن',
#  'ركوب',
#  'القطار',
#  'فتاة',
#  'صغيرة',
#  'في',
#  'قطار',
#  'تقرأ',
#  'كتابا',
#  'عن',
#  'ركوب',
#  'القطار',
#  'فتاة',
#  'صغيرة',
#  'تجلس',
#  'على',
#  'مقعد',
#  'وتنظر',
#  'إلى',
#  'كتيب',
#  'القطار',
#  'كلب',
#  'أسود',
#  'يركض',
#  'خلف',
#  'كلب',
#  'أسود',
#  'على',
#  'شاطئ',
#  'صخري',
#  'كلب',
#  'بني',
#  'يركض',
#  'خلف',
#  'الكلب',
#  'الأسود',
#  'اثنين',
#  'من',
#  'الكلاب',
#  'يلعبون',
#  'على',
#  'الشاطئ',
#  'صبي',
#  'ينزل',
#  'عن',
#  'لوح',
#  'الغطس',
#  'العالي',
#  'طفل',
#  'يقفز',
#  'من',
#  'لوحة',
#  'غوص',
#  'عالية',
#  'في',
#  'البركة',
#  'طفل',
#  'صغير',
#  'يقفز',
#  'من',
#  'اللوح',
#  'العالي',
#  'في',
#  'البركة',
#  'رجل',
#  'يقف',
#  'بجانب',
#  'نافذة',
#  'يخلع',
#  'قميصه',
#  'رجل',
#  'يقف',
#  'بمصعد',
#  'ورأسه',
#  'إلى',
#  'أسفل',
#  'رجل',
#  'يرتدي',
#  'قميصه',
#  'بالقرب',
#  'من',
#  'مصعد',
#  'كلب',
#  'خفيف',
#  'اللون',
#  'يركض',
#  'على',
#  'الشاطئ',
#  ...]

# %%
len(vocabulary)
# Out:
# 180095

# %%
#convert to dataframe
vocabs = pd.DataFrame.from_dict(val_count, orient='index').reset_index()
vocabs.columns = ['word','count']
vocabs = vocabs.sort_values(by='count', ascending=False)
vocabs.head()
# Out:
#    word  count
# 9    في  11109
# 24  على   7574
# 87   من   4723
# 15  كلب   4118
# 45  رجل   4029

# %% [markdown]
# > #### in the cell bellow a bar chart that show how many times each word rpeated in the dataset

# %%
plt.rcParams["figure.figsize"] = [16, 6]

vocabs.head(30).plot(kind='bar', x='word', y='count')

plt.xlabel("Words")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# > #### here we added start and end before and affter each caption as part of preprossesing and data cleaning

# %%
df['Captions'] = "<start> " + df['Captions'] + " <end>"
annotations = df['Captions']

all_img_path= list(df['Path'])

print("Total captions present in the dataset: "+ str(len(annotations)))
print("Total images present in the dataset: " + str(len(all_img_path)))
# Out:
# Total captions present in the dataset: 24273
# Total images present in the dataset: 24273

# %%
type(annotations)
# Out:
# pandas.core.series.Series

# %%
df.head()
# Out:
#                           ID  \
# 0  1000268201_693b08cb0e.jpg
# 1  1000268201_693b08cb0e.jpg
# 2  1000268201_693b08cb0e.jpg
# 3  1001773457_577c3a7d70.jpg
# 4  1001773457_577c3a7d70.jpg
#
#                                             Captions  \
# 0       <start> طفلة صغيرة تتسلق إلى مسرح خشبي <end>
# 1    <start> طفلة صغيرة تتسلق الدرج إلى منزلها <end>
# 2  <start> فتاة صغيرة في ثوب وردي تذهب إلى المقصو...
# 3  <start> كلب أسود وكلب ثلاثي الألوان يلعبان مع ...
# 4  <start> كلب أسود وكلب أبيض ببقع بنية يحدقان في...
#
#                                                 Path
# 0  /Users/norahalqahtani/DatascienceBootcamp/Deep...
# 1  /Users/norahalqahtani/DatascienceBootcamp/Deep...
# 2  /Users/norahalqahtani/DatascienceBootcamp/Deep...
# 3  /Users/norahalqahtani/DatascienceBootcamp/Deep...
# 4  /Users/norahalqahtani/DatascienceBootcamp/Deep...

# %%
df.Path[0]
# Out:
# '/Users/norahalqahtani/DatascienceBootcamp/Deep-Learning/Final-Project/AAA/Arabic-Image-Captioning/data/Flickr8k_Dataset/Flicker8k_Dataset//1000268201_693b08cb0e.jpg'

# %%
type(all_img_path)
# Out:
# list

# %% [markdown]
# ## Pre-Processing the captions
# 1.We will tokenize the captions and build the vocabulary which will be used to generate the caption for the image.
#
# 2.We will keep only 5000 most used words and replace all other words with the unknown token "UNK".
#
# 3.Create word-to-index and index-to-word mappings.
#
# 4.Pad all sequences vectors to be the same length as the longest one.

# %%
# create the tokenizer
def tokenize(captions):
    
    special_chars =  '''`÷×؛_()*&^%][ـ،/:"؟.,'{}~¦+|!”…“–ـ'''
    
    tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=5000,
                                                  oov_token="UNK",
                                                  filters=special_chars)
    tokenizer.fit_on_texts(captions)   
   
    return tokenizer 


img_captions, img_name_vector = shuffle(annotations, all_img_vector, random_state=42)
tokenizer = tokenize(img_captions)

# %%
# Create word-to-index and index-to-word mapping

def word_2_index(word):
    return tokenizer.word_index[word]
    
def index_2_word(index):
    return tokenizer.index_word[index]

print(index_2_word(10))
print(word_2_index('طفل'))
# Out:
# يرتدي
# 22

# %%
import operator
plt.rcParams["figure.figsize"] = [16, 6]

words = sorted(tokenizer.word_counts.items(), key=operator.itemgetter(1),reverse=True)
vocabs = pd.DataFrame(words)
vocabs.columns = ['word','count']
vocabs.head(30).plot(kind='bar', x='word', y='count')

plt.xlabel("Words")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
caption_sequences = tokenizer.texts_to_sequences(img_captions)
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(caption_sequences, padding='post')

print("The shape of Caption vector is :" + str(cap_vector.shape))
# Out:
# The shape of Caption vector is :(24273, 27)

# %% [markdown]
# ## Pre-Processing the images
#
# 1.Resize them into the shape of (299, 299)
#
# 3.Normalize the image within the range of -1 to 1, such that it is in correct format for InceptionV3.

# %%
def preprocess_the_image(imagePath):
    image = tf.io.read_file(imagePath)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, (299, 299))
    image = tf.keras.applications.inception_v3.preprocess_input(image)
    return image, imagePath

allImages = sorted(set(img_name_vector))

train_dataset = tf.data.Dataset.from_tensor_slices(allImages)
train_dataset = train_dataset.map(preprocess_the_image, num_parallel_calls=tf.data.experimental.AUTOTUNE).batch(64)

# %% [markdown]
# ## Create the train & test data
# 1. We will combine both images & captions to create the train & test dataset using tf.data.Dataset API. Create the train-test split using 80-20 ratio & random state = 42
#
# 2. We shuffle and batch while building the dataset
#
# 3. The shape of each image in the dataset after building should be (batch_size, 299, 299, 3)
#
# 4. The shape of each caption in the dataset after building should be (batch_size, max_len)

# %%
image_train, image_test, captions_train, captions_test = train_test_split(img_name_vector,
                                                                          cap_vector, 
                                                                          test_size=0.2, 
                                                                          random_state=42)

# %%
sample_img_batch, sample_cap_batch = next(iter(train_dataset))
print(sample_img_batch.shape)
print(sample_cap_batch.shape)
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
img_to_cap_vector = collections.defaultdict(list)

for img,cap in zip(img_name_vector, cap_vector):
    img_to_cap_vector[img].append(cap)

# %%
def vector_to_sentence(caplist):
    captions_word =[]
    for captions in caplist:
        list_caption = list(captions)

        captions_word.append(' '.join(tokenizer.index_word[i] for i in list_caption))
    return captions_word

# %% [markdown]
# ## Load the pre-trained Imagenet weights of Inception net V3
#
# 1.We will extract the features of the mage using the last layer of pre-trained model. Including this as part of training will lead to higher computational time.
#
# 2. The shape of the output of this pre-trained NN's layer is 8x8x2048.

# %%
image_model = tf.keras.applications.InceptionV3(include_top=False,weights='imagenet')

new_input = image_model.input
hidden_layer = image_model.layers[-1].output # take only the last layer

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)

# %% [markdown]
# ## Extract the features from images

# %%
from tqdm import tqdm

all_features_dict = {}
for img,path in tqdm(train_dataset):
    batch_features = image_features_extract_model(img)
    batch_features = tf.reshape(batch_features,
                              (batch_features.shape[0], -1, batch_features.shape[3]))
    
    for bf, p in zip(batch_features, path):
        file_name = p.numpy().decode("utf-8")
        all_features_dict[file_name] = bf.numpy()
# Out:
# 100%|██████████| 127/127 [22:22<00:00, 10.57s/it]

# %%
#save image features to pickle file
pickle.dump(all_features_dict, open(file_name,'wb'))

# %%
len(file_name)
# Out:
# 163

# %% [markdown]
# ## Shuffle the processed Train and Test Datasets

# %%
def feature_tensor(img_name, cap):
    img_tensor = all_features_dict[img_name.decode("utf-8")]
    return img_tensor, cap

BATCH_SIZE = 64
BUFFER_SIZE = 1000
train_dataset = tf.data.Dataset.from_tensor_slices((image_train, captions_train))

train_dataset = train_dataset.map(lambda item1, item2: tf.numpy_function(
                                   feature_tensor, [item1, item2], [tf.float32, tf.int32]), num_parallel_calls=tf.data.AUTOTUNE)

train_dataset = train_dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
train_dataset = train_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)


test_dataset = tf.data.Dataset.from_tensor_slices((image_test, captions_test))

test_dataset = test_dataset.map(lambda item1, item2: tf.numpy_function(
          feature_tensor, [item1, item2], [tf.float32, tf.int32]),
          num_parallel_calls=tf.data.AUTOTUNE)

test_dataset = test_dataset.batch(BATCH_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
train_img_batch, train_cap_batch = next(iter(train_dataset))
print(train_img_batch.shape)
print(train_cap_batch.shape)
# Out:
# (64, 64, 2048)
# (64, 27)

# %%
sample_img_batch, sample_cap_batch = next(iter(test_dataset))
print(sample_img_batch.shape)
print(sample_cap_batch.shape)
# Out:
# (64, 64, 2048)
# (64, 27)

# %% [markdown]
# ## Model Building
# Build the Encoder, Attention model & Decoder

# %%
embedding_dim = 256 
units = 512
vocab_size = 5001 #top 5,000 words +1
train_num_steps = len(image_train) // BATCH_SIZE 
test_num_steps = len(image_test) // BATCH_SIZE

# %% [markdown]
# ### Encoder

# %%
class Encoder(Model):
    def __init__(self,embed_dim):
        super(Encoder, self).__init__()
        self.dense = Dense(embed_dim)
        
    def call(self, features):
        features = self.dense(features)
        features = relu(features)
        
        return features

# %%
encoder=Encoder(embedding_dim)

# %% [markdown]
# ### Attention model

# %%
class Attention_model(Model):
    def __init__(self, units):
        super(Attention_model, self).__init__()
        self.W1 = Dense(units)
        self.W2 = Dense(units)
        self.V = Dense(1)
        self.units = units

    def call(self, features, hidden):
        hidden_with_time_axis = tf.expand_dims(hidden, 1)
        score = self.V(tanh(self.W1(features) + self.W2(hidden_with_time_axis)))
        attention_weights = softmax(score, axis = 1)
        context_vector = attention_weights * features
        context_vector = tf.reduce_sum(context_vector,axis = 1)

        return context_vector, attention_weights

# %% [markdown]
# ### Decoder

# %%
class Decoder(Model):
    def __init__(self, embed_dim, units, vocab_size):
        super(Decoder, self).__init__()
        self.units=units
        self.attention = Attention_model(self.units)
        self.embed = Embedding(vocab_size,embed_dim)
        self.gru = GRU(self.units, return_sequences=True, return_state=True, recurrent_initializer='glorot_uniform')
        self.d1 = Dense(self.units)
        self.d2 = Dense(vocab_size)
        

    def call(self,x,features, hidden):
        context_vector, attention_weights = self.attention(features, hidden)
        embed = self.embed(x)
        embed = tf.concat([tf.expand_dims(context_vector,1),embed],axis=-1)
        output,state = self.gru(embed)
        output = self.d1(output)
        output = tf.reshape(output, (-1, output.shape[2]))
        output = self.d2(output)
        
        return output,state, attention_weights
    
    def init_state(self, batch_size):
        return tf.zeros((batch_size, self.units))

# %%
decoder=Decoder(embedding_dim, units, vocab_size)

# %%
features=encoder(sample_img_batch)

hidden = decoder.init_state(batch_size=sample_cap_batch.shape[0])
dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * sample_cap_batch.shape[0], 1)

predictions, hidden_out, attention_weights= decoder(dec_input, features, hidden)
print('Feature shape from Encoder: {}'.format(features.shape))
print('Predcitions shape from Decoder: {}'.format(predictions.shape))
print('Attention weights shape from Decoder: {}'.format(attention_weights.shape))
# Out:
# Feature shape from Encoder: (64, 64, 256)
# Predcitions shape from Decoder: (64, 5001)
# Attention weights shape from Decoder: (64, 64, 1)

# %% [markdown]
# ## Model training & optimization
# - We will use Adam optimizer with default learning rate, however we can try learning rate hyper parameter tuning incase we can't reach the global minima
# - Cross entropy loss metrics in order to calculate the train and test loss

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits= True, reduction='none') #define your loss object
metrics = tf.keras.metrics.Mean('train_loss',dtype=tf.float32)

# %%
def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %% [markdown]
# ## Create checkpoints during model traning

# %%
checkpoint_path = "./checkpoints/train"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer = optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
    start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])

# %% [markdown]
# ## Override the tensorflow training/test steps
# - override with Encoder, Attention model, Decoder steps

# %%
@tf.function
def train_step(img_tensor, target):
    loss = 0
    hidden = decoder.init_state(batch_size=target.shape[0])
    dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)
    
    with tf.GradientTape() as tape:
        features = encoder(img_tensor,training =True)

        for i in range(1, target.shape[1]):
            predictions, hidden, _ = decoder(dec_input, features, hidden)

            loss += loss_function(target[:, i], predictions)

            dec_input = tf.expand_dims(target[:, i], 1)

    total_loss = (loss / int(target.shape[1]))

    trainable_variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, trainable_variables)

    optimizer.apply_gradients(zip(gradients, trainable_variables))
    metrics(loss)    
        
    return loss, total_loss

# %%
@tf.function
def test_step(img_tensor, target):
    loss = 0
    
    hidden = decoder.init_state(batch_size=target.shape[0])
    dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)
    features = encoder(img_tensor)
    for i in range(1, target.shape[1]):
            predictions, hidden, _ = decoder(dec_input, features, hidden)

            loss += loss_function(target[:, i], predictions)
            predicted_id = tf.argmax(predictions[0])
            dec_input = tf.expand_dims([predicted_id] * target.shape[0] , 1)
   
    avg_loss = (loss / int(target.shape[1]))
        
    return loss, avg_loss

# %%
def test_loss_cal(test_dataset):
    total_loss = 0

    for (batch,(img_tensor,target)) in enumerate(test_dataset):
        batch_loss, t_loss = test_step(img_tensor, target)
        total_loss += t_loss

    avg_test_loss = total_loss/int(target.shape[1])
    
    return avg_test_loss

# %%
import datetime,time

loss_plot = []
test_loss_plot = []
EPOCHS = 15 
# 15 epoches should be enough
# we can try with higher number of epochs in order to get higher accuracy 
# but it might decrease as well so we can do check pointing and find the best model

best_test_loss=100
for epoch in tqdm(range(0, EPOCHS)):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(train_dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss
    avg_train_loss = total_loss / train_num_steps
        
    loss_plot.append(avg_train_loss)    
    test_loss = test_loss_cal(test_dataset)
    test_loss_plot.append(test_loss)
    
    print ('For epoch: {}, the train loss is {:.3f}, & test loss is {:.3f}'.format(epoch+1,avg_train_loss,test_loss))
    print ('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    
    if test_loss < best_test_loss:
        print('Test loss has been reduced from %.3f to %.3f' % (best_test_loss, test_loss))
        best_test_loss = test_loss
        ckpt_manager.save()
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# For epoch: 1, the train loss is 1.595, & test loss is 5.508
# Time taken for 1 epoch 679.3718061447144 sec
#
# Test loss has been reduced from 100.000 to 5.508
#  25%|██▌       | 2/8 [21:13<1:02:55, 629.23s/it]
# For epoch: 2, the train loss is 1.244, & test loss is 5.710
# Time taken for 1 epoch 593.8864047527313 sec
#  38%|███▊      | 3/8 [32:44<54:47, 657.43s/it]
# For epoch: 3, the train loss is 1.095, & test loss is 5.760
# Time taken for 1 epoch 690.9817838668823 sec
#  50%|█████     | 4/8 [48:53<52:01, 780.36s/it]
# For epoch: 4, the train loss is 0.998, & test loss is 5.951
# Time taken for 1 epoch 968.7948760986328 sec
#  62%|██████▎   | 5/8 [1:01:47<38:54, 778.18s/it]
# For epoch: 5, the train loss is 0.922, & test loss is 6.129
# Time taken for 1 epoch 774.3182897567749 sec
#  75%|███████▌  | 6/8 [1:14:12<25:33, 766.74s/it]
# For epoch: 6, the train loss is 0.856, & test loss is 6.118
# Time taken for 1 epoch 744.5220899581909 sec
#  88%|████████▊ | 7/8 [1:27:19<12:53, 773.37s/it]
# For epoch: 7, the train loss is 0.795, & test loss is 6.332
# Time taken for 1 epoch 787.0172448158264 sec
# 100%|██████████| 8/8 [1:40:14<00:00, 751.81s/it]
# For epoch: 8, the train loss is 0.739, & test loss is 6.515
# Time taken for 1 epoch 775.2001559734344 sec

# %%
#ckpt_manager.save("model_weight.h5")

# %%
plt.plot(loss_plot)
plt.plot(test_loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %% [markdown]
# ## Model Evaluation
# 1. Define the evaluation function using greedy search
# 2. Test it on a sample data using BLEU score

# %% [markdown]
# ### Greedy Search

# %%
def evaluate(image):
    max_length = cap_vector.shape[1]
    attention_features_shape = 64
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.init_state(batch_size=1)
    
    pimg, path = preprocess_the_image(image)

    temp_input = tf.expand_dims(pimg, 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input,features,hidden) # get the output from decoder
        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        result.append(tokenizer.index_word[predicted_id])

        if tokenizer.index_word[predicted_id] == '<end>':
            return result, attention_plot, predictions

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot, predictions

# %%
def plot_attmap(caption, weights, image):

    fig = plt.figure(figsize=(10, 10))
    temp_img = np.array(Image.open(image))
    
    len_cap = len(caption)
    for cap in range(len_cap):
        weights_img = np.reshape(weights[cap], (8,8))
        weights_img = np.array(Image.fromarray(weights_img).resize((224, 224), Image.LANCZOS))
        
        ax = fig.add_subplot(len_cap//2, len_cap//2, cap+1)
        ax.set_title(caption[cap], fontsize=15)
        
        img=ax.imshow(temp_img)
        
        ax.imshow(weights_img, cmap='gist_heat', alpha=0.6,extent=img.get_extent())
        ax.axis('off')
    plt.subplots_adjust(hspace=0.2, wspace=0.2)
    plt.show()

# %%
def filt_text(text):
    filt=['<start>','<unk>','<end>'] 
    temp= text.split()
    [temp.remove(j) for k in filt for j in temp if k==j]
    text=' '.join(temp)
    return text

# %%
test_image = '/Users/norahalqahtani/DatascienceBootcamp/Deep-Learning/Final-Project/iimg/download.jpg'
real_caption = '<start> NaN <end>'

result, attention_plot, pred_test = evaluate(test_image)

real_caption=filt_text(real_caption)      

pred_caption=' '.join(result).rsplit(' ', 1)[0]

real_appn = []
real_appn.append(real_caption.split())
reference = real_appn
candidate = pred_caption.split()

score = sentence_bleu(reference, candidate, weights=(0,0,1,0))
print(f"BELU score: {score*100}")

print('Prediction Caption:', pred_caption)
plot_attmap(result, attention_plot, test_image)

Image.open(test_image)
# Out:
# BELU score: 0
# Prediction Caption: لاعب كرة قدم الشابة باللون الأسود والأصفر
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x7FED98E08910>

# %% [markdown]
# ## convert Text-to-speech
# - gTTS library can be used to read the predicted caption for blind person

# %%
#!pip install pydotplus
#!pip install googletrans
#!pip install gTTS

# %%
import pydotplus
from IPython.display import display, Image
import googletrans  
from gtts import gTTS
import IPython.display as ipd

# %%
tts = gTTS(pred_caption, lang='ar')
tts.save('test.mp3')
audio_path="test.mp3"

ipd.Audio(audio_path, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
